# %%
from pyspark import SparkConf, SparkContext

# %%
# Prerequisites: Ensure PySpark is installed and the file exists at the specified path.

# Initialize SparkContext
conf = SparkConf().setAppName("customer_purchase")
sc = SparkContext(conf=conf)
# Out:
# 25/04/12 11:14:14 WARN Utils: Your hostname, dell resolves to a loopback address: 127.0.1.1; using 192.168.183.130 instead (on interface ens33)
# 25/04/12 11:14:14 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/04/12 11:14:16 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Read the CSV file into an RDD
file_path = "/home/ubuntu/project/pyspark/files/customerorders-201008-180523.csv"
rdd = sc.textFile(file_path)

# %%
# Split the CSV lines and extract relevant fields (CustomerID and PurchaseAmount)
rdd_mapped = rdd.map(lambda line: line.split(",")) \
                .map(lambda fields: (fields[0], float(fields[2])))  # (CustomerID, PurchaseAmount)
# Out:
# 25/04/12 11:14:30 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
# Aggregate purchase amounts per customer
rdd_aggregated = rdd_mapped.reduceByKey(lambda x, y: x + y)

# %%
# Sort the aggregated results by ascending purchase amount
rdd_sorted = rdd_aggregated.sortBy(lambda x: x[1], ascending=True)

# %%
# Collect and print the results
results = rdd_sorted.collect()
for customer, total in results:
    print(f"CustomerID: {customer}, TotalPurchase: {total}")
# Out:
# CustomerID: 45, TotalPurchase: 3309.3799999999997
# CustomerID: 79, TotalPurchase: 3790.5699999999997
# CustomerID: 96, TotalPurchase: 3924.2300000000005
# CustomerID: 23, TotalPurchase: 4042.65
# CustomerID: 99, TotalPurchase: 4172.29
# CustomerID: 75, TotalPurchase: 4178.5
# CustomerID: 36, TotalPurchase: 4278.049999999999
# CustomerID: 98, TotalPurchase: 4297.259999999999
# CustomerID: 47, TotalPurchase: 4316.299999999998
# CustomerID: 77, TotalPurchase: 4327.73
# CustomerID: 13, TotalPurchase: 4367.619999999999
# CustomerID: 48, TotalPurchase: 4384.33
# CustomerID: 49, TotalPurchase: 4394.6
# CustomerID: 94, TotalPurchase: 4475.570000000001
# CustomerID: 67, TotalPurchase: 4505.79
# CustomerID: 50, TotalPurchase: 4517.2699999999995
# CustomerID: 78, TotalPurchase: 4524.51
# CustomerID: 5, TotalPurchase: 4561.07
# CustomerID: 57, TotalPurchase: 4628.4
# CustomerID: 83, TotalPurchase: 4635.8
# CustomerID: 91, TotalPurchase: 4642.26
# CustomerID: 74, TotalPurchase: 4647.130000000001
# CustomerID: 84, TotalPurchase: 4652.9400000000005
# CustomerID: 3, TotalPurchase: 4659.63
# CustomerID: 12, TotalPurchase: 4664.589999999999
# CustomerID: 66, TotalPurchase: 4681.92
# CustomerID: 56, TotalPurchase: 4701.02
# CustomerID: 21, TotalPurchase: 4707.41
# CustomerID: 80, TotalPurchase: 4727.86
# CustomerID: 14, TotalPurchase: 4735.030000000001
# CustomerID: 37, TotalPurchase: 4735.200000000001
# CustomerID: 7, TotalPurchase: 4755.069999999999
# CustomerID: 44, TotalPurchase: 4756.890000000001
# CustomerID: 31, TotalPurchase: 4765.049999999999
# CustomerID: 82, TotalPurchase: 4812.49
# CustomerID: 4, TotalPurchase: 4815.050000000001
# CustomerID: 10, TotalPurchase: 4819.7
# CustomerID: 88, TotalPurchase: 4830.55
# CustomerID: 20, TotalPurchase: 4836.860000000001
# CustomerID: 89, TotalPurchase: 4851.48
# CustomerID: 95, TotalPurchase: 4876.839999999998
# CustomerID: 38, TotalPurchase: 4898.460000000001
# CustomerID: 76, TotalPurchase: 4904.210000000001
# CustomerID: 86, TotalPurchase: 4908.810000000001
# CustomerID: 27, TotalPurchase: 4915.89
# CustomerID: 18, TotalPurchase: 4921.269999999999
# CustomerID: 53, TotalPurchase: 4945.300000000001
# CustomerID: 1, TotalPurchase: 4958.600000000001
# CustomerID: 51, TotalPurchase: 4975.220000000001
# CustomerID: 16, TotalPurchase: 4979.06
# CustomerID: 30, TotalPurchase: 4990.72
# CustomerID: 28, TotalPurchase: 5000.709999999999
# CustomerID: 22, TotalPurchase: 5019.449999999999
# CustomerID: 29, TotalPurchase: 5032.530000000001
# CustomerID: 17, TotalPurchase: 5032.68
# CustomerID: 60, TotalPurchase: 5040.709999999999
# CustomerID: 25, TotalPurchase: 5057.610000000001
# CustomerID: 19, TotalPurchase: 5059.43
# CustomerID: 81, TotalPurchase: 5112.709999999999
# CustomerID: 69, TotalPurchase: 5123.01
# CustomerID: 65, TotalPurchase: 5140.35
# CustomerID: 11, TotalPurchase: 5152.289999999999
# CustomerID: 35, TotalPurchase: 5155.420000000001
# CustomerID: 40, TotalPurchase: 5186.429999999999
# CustomerID: 87, TotalPurchase: 5206.4
# CustomerID: 52, TotalPurchase: 5245.0599999999995
# CustomerID: 26, TotalPurchase: 5250.4
# CustomerID: 62, TotalPurchase: 5253.3200000000015
# CustomerID: 33, TotalPurchase: 5254.660000000002
# CustomerID: 24, TotalPurchase: 5259.92
# CustomerID: 93, TotalPurchase: 5265.75
# CustomerID: 64, TotalPurchase: 5288.689999999999
# CustomerID: 90, TotalPurchase: 5290.41
# CustomerID: 55, TotalPurchase: 5298.089999999999
# CustomerID: 9, TotalPurchase: 5322.65
# CustomerID: 34, TotalPurchase: 5330.8
# CustomerID: 72, TotalPurchase: 5337.439999999999
# CustomerID: 70, TotalPurchase: 5368.249999999999
# CustomerID: 43, TotalPurchase: 5368.83
# CustomerID: 92, TotalPurchase: 5379.279999999999
# CustomerID: 6, TotalPurchase: 5397.879999999999
# CustomerID: 15, TotalPurchase: 5413.51
# CustomerID: 63, TotalPurchase: 5415.1500000000015
# CustomerID: 58, TotalPurchase: 5437.73
# CustomerID: 32, TotalPurchase: 5496.05
# CustomerID: 61, TotalPurchase: 5497.4800000000005
# CustomerID: 85, TotalPurchase: 5503.43
# CustomerID: 8, TotalPurchase: 5517.24
# CustomerID: 0, TotalPurchase: 5524.949999999999
# CustomerID: 41, TotalPurchase: 5637.620000000001
# CustomerID: 59, TotalPurchase: 5642.889999999999
# CustomerID: 42, TotalPurchase: 5696.840000000002
# CustomerID: 46, TotalPurchase: 5963.109999999999
# CustomerID: 97, TotalPurchase: 5977.1900000000005
# CustomerID: 2, TotalPurchase: 5994.59
# CustomerID: 71, TotalPurchase: 5995.660000000002
# CustomerID: 54, TotalPurchase: 6065.390000000001
# CustomerID: 39, TotalPurchase: 6193.110000000001
# CustomerID: 73, TotalPurchase: 6206.200000000001
# CustomerID: 68, TotalPurchase: 6375.450000000001
